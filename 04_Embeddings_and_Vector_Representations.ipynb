# %% [markdown]
# # 🔢 Notebook 04: Embeddings and Vector Representations
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand what embeddings are
# 2. Use OpenAI Embeddings
# 3. Use Google Gemini Embeddings
# 4. Compare embedding models
# 5. Calculate similarity between vectors

# %% [markdown]
# # 🔢 Notebook 04: Embeddings and Vector Representations
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand what embeddings are
# 2. Use OpenAI Embeddings
# 3. Use Google Gemini Embeddings
# 4. Compare embedding models
# 5. Calculate similarity between vectors

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print("✅ Setup complete")
# Out:
# ✅ Setup complete

# %% [markdown]
# ## 1. What are Embeddings? 🤔
#
# ### 🔰 BEGINNER
#
# **Embeddings** convert text into numbers (vectors) that capture meaning.
#
# Think of it like a GPS coordinate:
# - "dog" → [0.2, 0.8, 0.1, ...] (1536 numbers)
# - "cat" → [0.3, 0.7, 0.2, ...] (close to "dog"!)
# - "car" → [0.9, 0.1, 0.8, ...] (far from "dog")
#
# Similar meanings = Similar vectors!

# %% [markdown]
# ## 2. OpenAI Embeddings

# %%
from langchain_openai import OpenAIEmbeddings

# Initialize
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# Create embedding for a query
query = "What is machine learning?"
query_vector = embeddings.embed_query(query)

print(f"Query: {query}")
print(f"Vector dimensions: {len(query_vector)}")
print(f"First 5 values: {query_vector[:5]}")

# Embed multiple documents
docs = [
    "Machine learning is a subset of AI",
    "Deep learning uses neural networks",
    "The weather is sunny today"
]

doc_vectors = embeddings.embed_documents(docs)
print(f"\nEmbedded {len(doc_vectors)} documents")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 # Create embedding for a query
#       7 query = "What is machine learning?"
# ----> 8 query_vector = embeddings.embed_query(query)
#      10 print(f"Query: {query}")
#      11 print(f"Vector dimensions: {len(query_vector)}")
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\langchain_openai\embeddings\base.py:752, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     742 """Call out to OpenAI's embedding endpoint for embedding query text.
#     743
#     744 Args:
#    (...)    749     Embedding for the text.
#     750 """
#     751 self._ensure_sync_client_available()
# --> 752 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\langchain_openai\embeddings\base.py:702, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     699 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     700 # This could be optimized to avoid double work when all texts are short enough.
#     701 engine = cast(str, self.deployment)
# --> 702 return self._get_len_safe_embeddings(
#     703     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     704 )
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\langchain_openai\embeddings\base.py:569, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     567 # Make API call with this batch
#     568 batch_tokens = tokens[i:batch_end]
# --> 569 response = self.client.create(input=batch_tokens, **client_kwargs)
#     570 if not isinstance(response, dict):
#     571     response = response.model_dump()
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\exact\anaconda3\envs\myenv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## 3. Google Gemini Embeddings

# %%
uv! pip install langchain-google-genai
# Out:
# Resolved 39 packages in 907ms
# ⠙ Preparing packages... (0/9)
# ⠙ Preparing packages... (0/9)----     0 B/11.23 KiB
# ⠙ Preparing packages... (0/9) 11.23 KiB/11.23 KiB
# cachetools ------------------------------ 11.23 KiB/11.23 KiB
# ⠙ Preparing packages... (0/9)---------     0 B/169.63 KiB
# cachetools ------------------------------ 11.23 KiB/11.23 KiB
# google-api-core ------------------------------     0 B/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------     0 B/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 14.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 30.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 46.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 62.87 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# ⠙ Preparing packages... (0/9)------------------     0 B/290.54 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# ⠙ Preparing packages... (0/9)----     0 B/417.50 KiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------     0 B/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# grpcio-status ------------------------------ 14.09 KiB/14.09 KiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------     0 B/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# langchain-google-genai ------------------------------     0 B/55.15 KiB
# google-api-core ------------------------------ 75.27 KiB/169.63 KiB
# google-auth ------------------------------ 16.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/290.54 KiB
# protobuf   ------------------------------     0 B/417.50 KiB
# google-ai-generativelanguage ------------------------------     0 B/1.34 MiB
# ⠙ Preparing packages... (0/9)----     0 B/11.27 MiB
# google-api-core ------------------------------ 139.27 KiB/169.63 KiB
# google-auth ------------------------------ 80.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 78.42 KiB/290.54 KiB
# protobuf   ------------------------------ 64.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 64.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 64.00 KiB/11.27 MiB
# google-api-core ------------------------------ 139.27 KiB/169.63 KiB
# google-auth ------------------------------ 80.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 78.42 KiB/290.54 KiB
# protobuf   ------------------------------ 64.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 64.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 80.00 KiB/11.27 MiB
# google-auth ------------------------------ 112.00 KiB/217.88 KiB
# googleapis-common-protos ------------------------------ 110.32 KiB/290.54 KiB
# protobuf   ------------------------------ 128.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 112.00 KiB/1.34 MiB
# ⠙ Preparing packages... (0/9)---- 144.00 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 222.42 KiB/290.54 KiB
# protobuf   ------------------------------ 224.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 238.42 KiB/290.54 KiB
# protobuf   ------------------------------ 224.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 238.42 KiB/290.54 KiB
# protobuf   ------------------------------ 240.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 240.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 240.24 KiB/11.27 MiB
# googleapis-common-protos ------------------------------ 254.42 KiB/290.54 KiB
# protobuf   ------------------------------ 255.89 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 272.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 272.00 KiB/11.27 MiB
# protobuf   ------------------------------ 288.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 288.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 272.00 KiB/11.27 MiB
# protobuf   ------------------------------ 384.00 KiB/417.50 KiB
# google-ai-generativelanguage ------------------------------ 384.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 384.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 496.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 464.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 608.00 KiB/1.34 MiB
# ⠹ Preparing packages... (5/9)---- 560.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 752.00 KiB/1.34 MiB
# ⠸ Preparing packages... (7/9)---- 704.00 KiB/11.27 MiB
# google-ai-generativelanguage ------------------------------ 1.05 MiB/1.34 MiB
# ⠸ Preparing packages... (7/9)---- 1.05 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 1.64 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 1.86 MiB/11.27 MiB
# ⠸ Preparing packages... (7/9)---- 3.60 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 4.95 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 6.73 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 7.10 MiB/11.27 MiB
# ⠼ Preparing packages... (8/9)---- 7.12 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 7.33 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 7.67 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 8.05 MiB/11.27 MiB
# ⠴ Preparing packages... (8/9)---- 8.95 MiB/11.27 MiB
# Prepared 9 packages in 1.03s
# Installed 13 packages in 39ms
#  + cachetools==6.2.2
#  + google-ai-generativelanguage==0.9.0
#  + google-api-core==2.28.1
#  + google-auth==2.43.0
#  + googleapis-common-protos==1.72.0
#  + grpcio==1.76.0
#  + grpcio-status==1.76.0
#  + langchain-google-genai==3.0.3
#  + proto-plus==1.26.1
#  + protobuf==6.33.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + rsa==4.9.1

# %%
# Google Gemini Embeddings
if os.getenv("GOOGLE_API_KEY"):
    from langchain_google_genai import GoogleGenerativeAIEmbeddings
    
    gemini_embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    
    vector = gemini_embeddings.embed_query("Hello world")
    print(f"Gemini vector dimensions: {len(vector)}")
else:
    print("⚠️ Google API key not found. Set GOOGLE_API_KEY in .env")
# Out:
# Gemini vector dimensions: 3072

# %% [markdown]
# ## 4. Similarity Calculation

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    """Calculate cosine similarity between two vectors"""
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Test similarity
texts = [
    "I love programming",
    "I enjoy coding",
    "The weather is nice"
]
vectors = [gemini_embeddings.embed_query(text) for text in texts] 
#vectors = [embeddings.embed_query(text) for text in texts]

print("Similarity Scores:")
print(f"'{texts[0]}' vs '{texts[1]}': {cosine_similarity(vectors[0], vectors[1]):.4f}")
print(f"'{texts[0]}' vs '{texts[2]}': {cosine_similarity(vectors[0], vectors[2]):.4f}")
print("\nSimilar meanings = Higher similarity score!")
# Out:
# Similarity Scores:
# 'I love programming' vs 'I enjoy coding': 0.8085
# 'I love programming' vs 'The weather is nice': 0.5685
#
# Similar meanings = Higher similarity score!

# %% [markdown]
# ## Summary
#
# ✅ Embeddings convert text to vectors
# ✅ OpenAI text-embedding-3-small: 1536 dimensions
# ✅ Google Gemini: 768 dimensions
# ✅ Cosine similarity measures vector similarity
#
# **Next:** Vector Stores for efficient search!
